# %% [markdown]
# Bonus Lecture #1: Doing Data Science with <a href="https://plot.ly/">plotly</a>
# =================

# %% [markdown]
# ### Exploring the US election
#
# In this lecture, we are going to explore some ways of visualizing data using plotly, a very cool visualization api which allows you to create professional-looking visualizations. We will do that in the context of Presidential election! We are going to combine data from various sources, just as you would do in real life data science! The data that we are using is a processed version of those found in the below sources.
#
# **US Election results** can be found <a href="http://www.stat.berkeley.edu/users/nolan/data/voteProject/2016_US_County_Level_Presidential_Results.csv">here</a>.
#
# **Median Income data by state** can be found here <a href="https://www.census.gov/prod/2012pubs/acsbr11-02.pdf">here</a>.
#
# **Gini coefficient** data lives <a href="http://www.census.gov/topics/income-poverty/income-inequality.html">here</a>.

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from datascience import *
import numpy as np
import math
import requests
import re
import json

py.sign_in('data8', 'qOP6GPnJlLfnS2TnwDvs')

# %% [markdown]
# ## Let's take a look at Michigan

# %%
#Let's find the voting and census data for all the Michigan counties
election_16 = Table.read_table("https://raw.githubusercontent.com/adnanhemani/data8-assets/master/merged_election_data.csv")
mi_voting_data = election_16.where(election_16.column("State") == "michigan")
mi_voting_data
# Out:
# Unnamed: 0 | County Name | State    | ObamaVotes.12 | RomneyVotes.12 | votes_dem.16 | votes_gop.16 | total_votes.16 | per_dem.16 | per_gop.16 | diff.16 | per_point_diff.16 | bushVote.04 | kerryVote.04 | Total.Precincts.08 | Precincts.Reporting.08 | Obama.08 | McCain.08 | Other.08 | name    | x_coord  | y_coord | state_abbr | total_population | white_population | white_population_error | black_population | black_population_error | total_households | average_household_size | average_family_size | fertility | enrolled_hs | enrolled_higher_ed | edu_less_than_9th | edu_hs_no_diploma | edu_hs_diploma | edu_college_no_degree | edu_college_bachelors | edu_college_graduate_professional | in_labor_force_yes | in_labor_force_no | public_transportation_to_work | working_at_home | occupation_management_business_science_arts | income_less_than_10000 | income_10000_to_24999 | income_25000_to_49999 | income_50000_to_99999 | income_100000_to_149999 | income_150000_to_199999 | income_more_than_200000
# 39         | alcona      | michigan | 2462          | 3571           | 1732         | 4201         | 6179           | 0.280304   | 0.679883   | 1037    | 1111              | 3590        | 2871         | 12                 | 12                     | 2896     | 3404      | 84       | Alcona  | -83.2729 | 44.7122 | MI         | 11238            | 10998            | 257                    | nan              | nan                    | 4608             | 2.43                   | 2.94                | 77        | 559         | 309                | 337               | 1064              | 3758           | 2012                  | 681                   | 424                               | 4137               | 5643              | 7                             | 313             | 809                                         | 363                    | 1229                  | 1520                  | 1194                  | 202                     | 202                     | 52
# 45         | alger       | michigan | 2212          | 2329           | 1663         | 2585         | 4513           | 0.368491   | 0.57279    | 2648    | 372               | 2316        | 2395         | 14                 | 14                     | 2472     | 2188      | 90       | Alger   | -86.4842 | 47.1604 | MI         | 9604             | 8366             | 498                    | 789              | 187                    | 3688             | 2.24                   | 2.73                | 69        | 545         | 255                | 358               | 661               | 3196           | 1382                  | 917                   | 330                               | 3788               | 4376              | 47                            | 224             | 915                                         | 296                    | 800                   | 1194                  | 1062                  | 237                     | 237                     | 47
# 47         | allegan     | michigan | 19594         | 29023          | 17932        | 33812        | 55153          | 0.325132   | 0.613058   | 515     | 673               | 32952       | 19227        | 48                 | 48                     | 23526    | 29526     | 1025     | Allegan | -86.25   | 42.565  | MI         | 111385           | 103163           | 717                    | 1433             | 317                    | 42078            | 2.62                   | 3.04                | 1725      | 6823        | 5093               | 3033              | 5061              | 28472          | 16513                 | 9689                  | 4460                              | 56049              | 29190             | 92                            | 1946            | 13907                                       | 2423                   | 6495                  | 12028                 | 15327                 | 4198                    | 4198                    | 762
# 59         | alpena      | michigan | 6549          | 7298           | 4877         | 9090         | 14688          | 0.33204    | 0.618873   | 1674    | 666               | 7665        | 7406         | 18                 | 18                     | 7705     | 7125      | 255      | Alpena  | -83.1976 | 45.037  | MI         | 29958            | 29241            | 819                    | nan              | nan                    | 13357            | 2.21                   | 2.7                 | 382       | 1644        | 1645               | 829               | 1822              | 7450           | 5409                  | 1938                  | 1370                              | 14353              | 10115             | 41                            | 665             | 3941                                        | 1119                   | 3524                  | 3876                  | 3528                  | 977                     | 977                     | 118
# 78         | antrim      | michigan | 5107          | 7917           | 4448         | 8469         | 13572          | 0.327734   | 0.624005   | 1623    | 704               | 8379        | 5072         | 16                 | 16                     | 6079     | 7506      | 267      | Antrim  | -85.1769 | 45.006  | MI         | 23975            | 23137            | 267                    | nan              | nan                    | 10043            | 2.33                   | 2.75                | 250       | 1287        | 741                | 398               | 1419              | 6473           | 3863                  | 2413                  | 1631                              | 11084              | 8458              | 62                            | 654             | 2706                                        | 669                    | 2141                  | 3043                  | 3008                  | 807                     | 807                     | 192
# 87         | arenac      | michigan | 3669          | 4054           | 2238         | 4704         | 7457           | 0.300121   | 0.630817   | 1034    | 830               | 4071        | 4076         | 20                 | 20                     | 4155     | 3807      | 166      | Arenac  | -83.7524 | 44.0455 | MI         | 16487            | 15781            | 679                    | nan              | nan                    | 6686             | 2.33                   | 2.83                | 112       | 951         | 521                | 672               | 1572              | 5041           | 2569                  | 843                   | 437                               | 7091               | 6591              | 69                            | 325             | 1654                                        | 570                    | 1626                  | 2241                  | 1780                  | 318                     | 318                     | 59
# 134        | baraga      | michigan | 1574          | 1866           | 1156         | 2158         | 3486           | 0.331612   | 0.619048   | 2       | 671               | 1977        | 1660         | 8                  | 8                      | 1725     | 1846      | 73       | Baraga  | -88.342  | 46.7154 | MI         | 8882             | 6671             | 714                    | 599              | 299                    | 3336             | 2.39                   | 2.94                | 87        | 480         | 238                | 482               | 678               | 2799           | 1342                  | 539                   | 203                               | 3841               | 3509              | 27                            | 81              | 1037                                        | 326                    | 620                   | 1098                  | 1019                  | 201                     | 201                     | 38
# 144        | barry       | michigan | 11496         | 16651          | 9109         | 19197        | 30265          | 0.300975   | 0.634297   | 10      | 840               | 18638       | 11312        | 25                 | 25                     | 13449    | 16431     | 685      | Barry   | -85.311  | 42.5978 | MI         | 59576            | 58075            | 1117                   | nan              | nan                    | 22843            | 2.6                    | 3.01                | 636       | 3644        | 3007               | 928               | 2883              | 16028          | 9836                  | 4152                  | 2494                              | 30505              | 15866             | 14                            | 762             | 7014                                        | 955                    | 3586                  | 6372                  | 8510                  | 2409                    | 2409                    | 416
# 156        | bay         | michigan | 26797         | 23735          | 21641        | 28327        | 52932          | 0.408845   | 0.535158   | 2233    | 100               | 25443       | 31041        | 89                 | 89                     | 32589    | 23794     | 1044     | Bay     | -83.9427 | 43.7208 | MI         | 108156           | 101781           | 650                    | 1582             | 440                    | 44345            | 2.41                   | 2.91                | 1271      | 6056        | 6707               | 2739              | 6679              | 26758          | 17321                 | 9178                  | 4226                              | 54158              | 32537             | 283                           | 1573            | 13927                                       | 3528                   | 7931                  | 13545                 | 13709                 | 4022                    | 4022                    | 634
# 194        | benzie      | michigan | 4683          | 5071           | 4108         | 5539         | 10221          | 0.401918   | 0.541923   | 393     | 149               | 5283        | 4383         | 13                 | 13                     | 5461     | 4687      | 171      | Benzie  | -86.2478 | 44.6304 | MI         | 17705            | 17059            | 1009                   | nan              | nan                    | 7366             | 2.35                   | 2.83                | 170       | 1032        | 753                | 232               | 1060              | 4302           | 2748                  | 1922                  | 1292                              | 8754               | 5599              | 34                            | 473             | 2441                                        | 372                    | 1314                  | 2510                  | 2419                  | 547                     | 547                     | 94
# ... (73 rows omitted)

# %%
# Add a new column indicating % unemployed and % of GOP vote per county
mi_voting_data = mi_voting_data.with_column("perc_labor_force", mi_voting_data.column("in_labor_force_yes")/(mi_voting_data.column("in_labor_force_yes") + mi_voting_data.column("in_labor_force_no")))
mi_voting_data = mi_voting_data.with_column("perc_gop_vote", mi_voting_data.column("votes_gop.16")/(mi_voting_data.column("votes_gop.16") + mi_voting_data.column("votes_dem.16")))

# %%
# Break the counties into 2 tables: one for Democrat-voting counties and the other for Republic-voting counties
gop_counties = mi_voting_data.where(mi_voting_data.column("perc_gop_vote") > 0.5)
dem_counties = mi_voting_data.where(mi_voting_data.column("perc_gop_vote") < 0.5)

# %%
trace_gop = go.Scatter(
    name = "Republican",
    x = gop_counties.column("perc_labor_force"),
    y = gop_counties.column("perc_gop_vote"),
    text = gop_counties.column("County Name"),
    mode = 'markers'
)

trace_dem = go.Scatter(
    name = "Democrat",
    x = dem_counties.column("perc_labor_force"),
    y = dem_counties.column("perc_gop_vote"),
    text = dem_counties.column("County Name"),
    mode = 'markers'
)

data = [trace_gop, trace_dem]

layout = go.Layout(
    title='Percent Unemployed versus GOP Votes in Michigan',
    xaxis = dict(
        title = "% Employed",
    ),
    yaxis = dict(
        title = "% Votes for Republicans",
    )
)

fig = go.Figure(data = data, layout = layout)

py.iplot(fig, filename='employment-vs-votes')
# Out:
# High five! You successfuly sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~data8/0 or inside your plot.ly account where it is named 'employment-vs-votes'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~data8/0.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Election Results Overview

# %%
#First off let's read in our data and take a quick look
#One easy way to read in your data from a csv file is using the datascience package's table
#You will learn more about the datascience package next week!
df = Table.read_table("https://raw.githubusercontent.com/adnanhemani/data8-assets/master/election_df_2016.csv").drop("code")
df.show(5)

# %%
#The first step is to extract the data we are interested in from our table
#all the statements below return the corresponding table columns in the form of a numpy array.
state_abbreviations = df.column("state_abbr").astype(str)
text_16 = df.column("text").astype(str)
perc_difference_16 = df.column("perc_diff").astype(str)
votes_dem_16 = df.column("votes_dem.16").astype(int)
votes_gop_16 = df.column("votes_gop.16").astype(int)
df_ = Table.read_table("https://raw.githubusercontent.com/adnanhemani/data8-assets/master/election_df_2012.csv")
perc_difference_12 = df_.column("perc_diff").astype(str)

# %%
#Determine the color scale that we will be using
scl = [[0, 'rgb(255, 0, 0)'],[0.25, 'rgb(255, 122, 122)'],[0.4, "rgb(247, 133, 133)"],[0.45, 'rgb(255, 153, 153)'],
       [0.5, 'rgb(255, 255, 255)'],[0.55, 'rgb(160, 160, 255)'],[0.6, 'rgb(133, 177, 247)'], [0.75, 'rgb(122,122,255)'],[1, 'rgb(0, 0, 255)']]

#first off we have to put the data in the right format
data = [ dict(
        type='choropleth',
        autocolorscale = False,
        locations = state_abbreviations, #the state abbreviations go here
        z = perc_difference_16.astype(float),
        locationmode = 'USA-states', #determine the type of map you want to make
        text = text_16, #this is the array containing the information we will see when we hover over our states
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "Percentage Difference"), #Title of our map
            colorscale = scl, #set the colorscale we created
            zmin = -0.5,
            zmax = 0.5
        ) ]

#make the layout that contains information about the map
layout = dict(
        title = '2016 Election Results',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )
    
fig = dict( data=data, layout=layout )
py.iplot( fig, filename='d3-cloropleth-map' )

# %%
#Now I want to calculate the percentage that each party got on each state - numpy math
perc_dem = votes_dem_16/(votes_dem_16+votes_gop_16)
perc_gop = votes_gop_16/(votes_dem_16+votes_gop_16)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace1 = go.Bar(
    y=state_abbreviations,
    x=perc_dem,
    name='Democrats',
    orientation = 'h',
    marker = dict(
        color = 'rgba(169, 228, 232, 0.4)',
        line = dict(
            color = 'rgba(169, 228, 232, 1.0)',
            width = 5)
    )
)
trace2 = go.Bar(
    y=state_abbreviations,
    x=perc_gop,
    name='Republicans',
    orientation = 'h',
    marker = dict(
        color = 'rgba(224, 92, 45, 0.6)',
        line = dict(
            color = 'rgba(224, 92, 45, 1.0)',
            width = 5)
    )
)

data = [trace1, trace2]
layout = go.Layout(
    barmode='stack'
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='marker-h-bar')

# %% [markdown]
# ## In how many states did each party improve their performance?
#
# This election was admittedly one of the most polarized of the recent years. So one question to ask is how did that affect the electoral map?

# %%
#explore in how many states republicans and democrats improved their percentage
perc_difference_12 = perc_difference_12.astype(float)
perc_difference_16 = perc_difference_16.astype(float)
diff = perc_difference_16-perc_difference_12
diff

# %%
#Get rid of the nan value
diff = diff[~np.isnan(diff)]
dems_improved = np.count_nonzero(diff>0)
republicans_improved = np.count_nonzero(diff<0)

# %%
#Bar chart
data = [go.Bar(
            x=['Democrats improved', 'Republicans improved'],
            y=[dems_improved, republicans_improved]
    )]
layout = go.Layout(
    title="In how many states did the two parties improve?"
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='basic-bar')

# %%
#This is very high level. Let's try to see how many states republicans actually converted compared to the 2012 election
gop_12 = perc_difference_12<0 #won by the gop in 2012
gop_16 = perc_difference_16<0 #won by the gop in 2016
lst = list(zip(gop_12, gop_16))
lst

# %%
from collections import Counter
counts = dict(Counter(lst))
counts

# %%
counts["democrat_to_democrat"] = counts.pop((False, False))
counts["democrat_to_republican"] = counts.pop((False, True))
counts["republican_to_republican"] = counts.pop((True, True))
counts["republican_to_democrat"] = 0
counts

# %%
#Get all items from a dictionary in alphabetical order of the keys
sorted_list = sorted(counts.items(), key=lambda x: x[0])
sorted_list

# %%
trace0 = go.Bar(
    x=['Democrat to Democrat', 'Democrat to Republican', 'Republican to Democrat',
       'Republican to Republican'],
    y=[val for key, val in sorted_list], #I want the keys in sorted order
    marker=dict(
        color=['rgba(204,204,204,1)','rgba(204,204,204,1)', 'rgba(204,204,204,1)', 'rgba(222,45,38,0.8)']),
)

data = [trace0]
layout = go.Layout(
    title='How many states did the two parties manage to convert?',
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='color-bar')

# %% [markdown]
# ## Voting and income inequality
#
# Now we will take a look at how income and income inequality relate to the voting patterns.

# %%
import csv
#we will need that dictionary to put our data in a similar format
with open('state_abbreviations.csv', 'r') as csv_file:
    reader = csv.reader(csv_file)
    state_abbr_dict = dict(reader)
state_abbr_dict['district of columbia'] = "DC"

# %%
import pprint
with open('gini_states_data.csv', 'r') as csv_file:
    reader = csv.reader(csv_file)
    gini_data = dict(reader)
    
#Put the data in the right format
for key in gini_data.keys():
    gini_data[key] = eval(gini_data[key])
    
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(gini_data)

# %%
#replace states by state abbreaviations
states_encoded = []
for state in gini_data['State']:
    state = state.lower() #convert to lowercase
    if state in state_abbr_dict.keys():
        states_encoded.append(state_abbr_dict[state])
gini_data['State'] = states_encoded

# %%
gini = list(zip(gini_data['Year'], gini_data['State'], gini_data['Gini']))
#keep data from 2010
gini_2010 = [i for i in gini if i[0]==2010]
len(gini_2010)

# %%
sorted(gini_2010, key = lambda x:x[1])

# %%
gini_2010.remove((2010, 'SD', 0.655813515))
len(gini_2010)

# %%
gini_2010 = dict([(i[1], i[2]) for i in gini_2010])
gini_2010

# %%
#income data
income = Table.read_table("states_median_income.csv")
income.show(5)

# %%
#format the income column
income.append_column("median_income",[int(i.replace(",", "")) for i in income.column("median_income")])
income.append_column("State", [state_abbr_dict[key] for key in income.column("State")])

# %%
median_income = income.sort("State").column("median_income")
gini = [i[1] for i in sorted(list(gini_2010.items()), key=lambda x:x[0])]

# %%
electoral = Table.read_table("electoral_votes.csv").select(["State", "electoral_votes"]).take(np.arange(51))
electoral['State'] = electoral.apply(lambda x: state_abbr_dict[x.lower()], "State")
electoral_votes = electoral.sort("State").column("electoral_votes")

# %%
hover_text = []
bubble_size = []
for i in range(len(state_abbreviations)): 
    hover_text.append(('State: {state}<br>'+
                          'Electoral Votes: {evotes}<br>'+
                          'Median income: {income}<br>'+
                          'Gini coefficient: {gini}<br>').format(state=state_abbreviations[i],
                                                evotes=electoral_votes[i],
                                                income=median_income[i],
                                                gini=gini[i]
                                                ))
    bubble_size.append(electoral_votes[i])

# %%
democratic_states = perc_difference_16>0
republicans_states = perc_difference_16<0

# %%
text = hover_text
size = bubble_size

trace0 = go.Scatter(
    x=median_income[democratic_states],
    y=np.array(gini)[democratic_states],
    mode='markers',
    name='Democratic',
    text=np.array(text)[democratic_states],
    marker=dict(
        symbol='circle',
        sizemode='diameter',
        sizeref=0.85,
        size=np.array(size)[democratic_states],
        line=dict(
            width=2
        )
    )
)
trace1 = go.Scatter(
    x=median_income[republicans_states],
    y=np.array(gini)[republicans_states],
    mode='markers',
    name='Republican',
    text=np.array(text)[republicans_states],
    marker=dict(
        sizemode='diameter',
        sizeref=0.85,
        size=np.array(size)[republicans_states],
        line=dict(
            width=2
        ), color = 'rgb(243, 0, 0)'
    )
)

data = [trace0, trace1]
layout = go.Layout(
    title = "Income inequality and the 2016 election",
    paper_bgcolor='rgb(243, 243, 243)',
    plot_bgcolor='rgb(243, 243, 243)',
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='2106')

# %% [markdown]
# ## Bonus material - County Level Map for Michigan

# %%
#Let's import geo data that will allow us to map all the counties
url = 'http://catalog.civicdashboards.com/dataset/08b4daa7-8888-4e03-ad73-ae2ff3c47771/resource/b12bbaa4-14df-4293-8636-2bb80804678c/download/89e296fe1c5c410d83c2d97155366e24temp.geojson'
michigan_data = requests.get(url)
michigan_data = michigan_data.json()
michigan_data
# Out:
# {'features': [{'geometry': {'coordinates': [[[[-85.864155, 46.702662],
#        [-85.864932, 46.504757999999995],
#        [-86.364953, 46.505852],
#        [-86.36526099999999, 46.331928999999995],
#        [-86.615397, 46.333262999999995],
#        [-86.615601, 46.158691],
#        [-87.11608, 46.158944999999996],
#        [-87.11663399999999, 46.494808],
#        [-87.112245, 46.749925999999995],
#        [-87.112695, 47.817997999999996],
#        [-86.94062199999999, 47.749905],
#        [-86.949226, 47.749905],
#        [-86.75012, 47.67196],
#        [-86.75012, 47.674910999999994],
#        [-86.631321, 47.624919999999996],
#        [-86.634344, 47.624919999999996],
#        [-86.625125, 47.617767],
#        [-86.625125, 47.620008],
#        [-86.50013, 47.568324],
#        [-86.25013899999999, 47.477903],
#        [-86.25013899999999, 47.474447999999995],
#        [-86.125141, 47.423468],
#        [-86.125142, 47.416744],
#        [-86.020032, 47.374962],
#        [-86.027345, 47.374961],
#        [-86.00014499999999, 47.361883],
#        [-86.00014399999999, 47.367278999999996],
#        [-85.854862, 47.305482],
#        [-85.858727, 47.249976],
#        [-85.854607, 47.249977],
#        [-85.864155, 46.702662]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26003', 'name': 'Alger County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.719578, 45.809332],
#        [-84.695497, 45.806269],
#        [-84.67654399999999, 45.801519],
#        [-84.639253, 45.787026],
#        [-84.625044, 45.779443],
#        [-84.586739, 45.750001999999995],
#        [-84.568844, 45.738077],
#        [-84.54171199999999, 45.723721999999995],
#        [-84.51003899999999, 45.709432],
#        [-84.483475, 45.700693],
#        [-84.44692599999999, 45.694703999999994],
#        [-84.40664, 45.692488],
#        [-84.366314, 45.695872],
#        [-84.353121, 45.699397],
#        [-84.250045, 45.739827999999996],
#        [-84.201062, 45.752275],
#        [-84.204263, 45.626247],
#        [-84.25202, 45.625997999999996],
#        [-84.24750999999999, 45.430872],
#        [-84.24938, 45.282073],
#        [-84.246613, 45.282073],
#        [-84.246634, 45.198718],
#        [-84.433876, 45.198969999999996],
#        [-84.734303, 45.201935999999996],
#        [-84.72985899999999, 45.401083],
#        [-84.73259499999999, 45.81033],
#        [-84.719578, 45.809332]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26031', 'name': 'Cheboygan County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.541006, 42.768175],
#        [-85.07424499999999, 42.770784],
#        [-85.075582, 42.683589],
#        [-85.07521899999999, 42.613859999999995],
#        [-85.071609, 42.421428],
#        [-85.35157799999999, 42.419722],
#        [-85.543191, 42.421433],
#        [-85.543239, 42.590905],
#        [-85.545107, 42.681428],
#        [-85.545564, 42.768139],
#        [-85.541006, 42.768175]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26015', 'name': 'Barry County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.418099, 42.420193999999995],
#        [-85.298879, 42.419849],
#        [-85.299557, 42.419340999999996],
#        [-85.297088, 42.249026],
#        [-85.29362599999999, 42.071553],
#        [-85.76294299999999, 42.069327],
#        [-85.766066, 42.244693],
#        [-85.764352, 42.420669],
#        [-85.53249799999999, 42.421521999999996],
#        [-85.418099, 42.420193999999995]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26077', 'name': 'Kalamazoo County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-87.636344, 45.898846],
#        [-87.61761299999999, 45.898841999999995],
#        [-87.61703899999999, 45.986005999999996],
#        [-87.367843, 45.985313],
#        [-87.368403, 45.899217],
#        [-87.32572499999999, 45.898623],
#        [-87.327472, 45.550506999999996],
#        [-87.12911799999999, 45.550484999999995],
#        [-87.127826, 45.409487],
#        [-87.17116999999999, 45.35254],
#        [-87.315422, 45.240657],
#        [-87.405694, 45.201969],
#        [-87.44250799999999, 45.076434],
#        [-87.585388, 45.096925],
#        [-87.59187999999999, 45.094688999999995],
#        [-87.62771699999999, 45.10335],
#        [-87.631535, 45.106224],
#        [-87.648191, 45.106367999999996],
#        [-87.652512, 45.108633],
#        [-87.65995199999999, 45.107512],
#        [-87.661296, 45.112566],
#        [-87.67244699999999, 45.121294],
#        [-87.678209, 45.130084],
#        [-87.675816, 45.135059],
#        [-87.68390199999999, 45.144135],
#        [-87.692375, 45.149505],
#        [-87.703492, 45.152206],
#        [-87.70953899999999, 45.15869],
#        [-87.71790999999999, 45.161190999999995],
#        [-87.727768, 45.169596],
#        [-87.736104, 45.172244],
#        [-87.73521, 45.177642],
#        [-87.741732, 45.198201],
#        [-87.736339, 45.204653],
#        [-87.726198, 45.209391],
#        [-87.726952, 45.218948999999995],
#        [-87.72135399999999, 45.226847],
#        [-87.724992, 45.23214],
#        [-87.71826399999999, 45.238333],
#        [-87.711339, 45.239965],
#        [-87.711315, 45.252396],
#        [-87.707758, 45.258637],
#        [-87.71045, 45.259324],
#        [-87.705643, 45.266104],
#        [-87.69878, 45.26942],
#        [-87.69824799999999, 45.281512],
#        [-87.69034099999999, 45.290217],
#        [-87.687499, 45.298055],
#        [-87.679091, 45.305841],
#        [-87.671889, 45.308105999999995],
#        [-87.672669, 45.310213],
#        [-87.661711, 45.320736],
#        [-87.661603, 45.327608],
#        [-87.655203, 45.331353],
#        [-87.647965, 45.339822999999996],
#        [-87.647729, 45.350721],
#        [-87.656447, 45.358413],
#        [-87.65735, 45.368753999999996],
#        [-87.673513, 45.376946],
#        [-87.675017, 45.382453999999996],
#        [-87.690281, 45.389821999999995],
#        [-87.69979699999999, 45.387927],
#        [-87.70832899999999, 45.381218],
#        [-87.720522, 45.376301999999995],
#        [-87.738823, 45.356851],
#        [-87.750928, 45.355036999999996],
#        [-87.754104, 45.349441999999996],
#        [-87.76212799999999, 45.348400999999996],
#        [-87.76926, 45.351195999999995],
#        [-87.783076, 45.349725],
#        [-87.79032199999999, 45.353451],
#        [-87.810076, 45.351268999999995],
#        [-87.823028, 45.35265],
#        [-87.82691799999999, 45.350538],
#        [-87.832612, 45.352249],
#        [-87.838141, 45.345101],
#        [-87.850133, 45.340435],
#        [-87.85041799999999, 45.347491999999995],
#        [-87.863489, 45.35302],
#        [-87.865763, 45.35628],
#        [-87.865344, 45.362096],
#        [-87.86916699999999, 45.366049],
#        [-87.875845, 45.365016999999995],
#        [-87.869771, 45.358616],
#        [-87.870367, 45.356266999999995],
#        [-87.881114, 45.351278],
#        [-87.888052, 45.354696999999994],
#        [-87.884855, 45.362792],
#        [-87.87148499999999, 45.371545999999995],
#        [-87.875424, 45.379373],
#        [-87.85941799999999, 45.388227],
#        [-87.85683, 45.393105999999996],
#        [-87.85913099999999, 45.398967],
#        [-87.849322, 45.403872],
#        [-87.850533, 45.411685],
#        [-87.85621599999999, 45.416101],
#        [-87.860432, 45.423504],
#        [-87.86169699999999, 45.434473],
#        [-87.85529799999999, 45.441379],
#        [-87.84742899999999, 45.444176999999996],
#        [-87.844804, 45.448406],
#        [-87.835562, 45.451102],
#        [-87.831217, 45.457184999999996],
#        [-87.81297599999999, 45.46416],
#        [-87.805773, 45.473138999999996],
#        [-87.806891, 45.479092],
#        [-87.79896, 45.485147],
#        [-87.79817299999999, 45.493666],
#        [-87.79276899999999, 45.499967],
#        [-87.79321499999999, 45.505027999999996],
#        [-87.798794, 45.506287],
#        [-87.802241, 45.513059],
#        [-87.80471999999999, 45.531244],
#        [-87.80339, 45.538272],
#        [-87.81373699999999, 45.548615999999996],
#        [-87.832968, 45.559461],
#        [-87.83186599999999, 45.567738999999996],
#        [-87.81042, 45.565307999999995],
#        [-87.80610399999999, 45.562863],
#        [-87.792372, 45.563055],
#        [-87.788798, 45.565947],
#        [-87.786766, 45.582828],
#        [-87.777199, 45.588498],
#        [-87.774682, 45.602024],
#        [-87.777937, 45.60444],
#        [-87.777671, 45.609204],
#        [-87.780845, 45.614599],
#        [-87.79588, 45.618846],
#        [-87.796983, 45.623613],
#        [-87.80452, 45.628986999999995],
#        [-87.810195, 45.638732],
#        [-87.824392, 45.64771],
#        [-87.822378, 45.660996999999995],
#        [-87.824191, 45.662043999999995],
#        [-87.80328999999999, 45.666494],
#        [-87.79727799999999, 45.670837999999996],
#        [-87.781623, 45.67328],
#        [-87.782226, 45.683053],
#        [-87.80907499999999, 45.699717],
#        [-87.805081, 45.704974],
#        [-87.810144, 45.710229999999996],
#        [-87.832695, 45.715312999999995],
#        [-87.84660199999999, 45.722544],
#        [-87.697159, 45.722986999999996],
#        [-87.696946, 45.898841999999995],
#        [-87.636344, 45.898846]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26109', 'name': 'Menominee County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.81737799999999, 44.689043],
#        [-85.81512, 44.774525],
#        [-85.694344, 44.775476999999995],
#        [-85.618033, 44.774557],
#        [-85.61705099999999, 44.775447],
#        [-85.612318, 44.785381],
#        [-85.609662, 44.798341],
#        [-85.614091, 44.822297999999996],
#        [-85.61386399999999, 44.828874],
#        [-85.591044, 44.876669],
#        [-85.591342, 44.88312],
#        [-85.59503699999999, 44.89459],
#        [-85.594725, 44.901089999999996],
#        [-85.570494, 44.930142],
#        [-85.562691, 44.948153999999995],
#        [-85.560194, 44.962664],
#        [-85.55698199999999, 45.017585],
#        [-85.550455, 45.051072999999995],
#        [-85.480674, 45.120326],
#        [-85.43294499999999, 45.021536999999995],
#        [-85.428855, 45.000116999999996],
#        [-85.429491, 44.984454],
#        [-85.42768799999999, 44.965272999999996],
#        [-85.430497, 44.95653],
#        [-85.442072, 44.938029],
#        [-85.445534, 44.930012999999995],
#        [-85.453294, 44.900825],
#        [-85.460357, 44.882607],
#        [-85.473841, 44.859449],
#        [-85.38198299999999, 44.859567999999996],
#        [-85.376751, 44.834447],
#        [-85.37397899999999, 44.828261999999995],
#        [-85.369304, 44.825762],
#        [-85.36363899999999, 44.825199],
#        [-85.345283, 44.827543],
#        [-85.342767, 44.825061],
#        [-85.339748, 44.818042999999996],
#        [-85.332836, 44.812371999999996],
#        [-85.334, 44.512302999999996],
#        [-85.817802, 44.512969],
#        [-85.81737799999999, 44.689043]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26055',
#     'name': 'Grand Traverse County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.237839, 46.245421],
#        [-85.113126, 46.245667],
#        [-85.112438, 46.158190999999995],
#        [-84.363503, 46.157984],
#        [-84.36309, 46.071580999999995],
#        [-84.23883599999999, 46.071456999999995],
#        [-84.239313, 45.98488],
#        [-84.11418499999999, 45.985216],
#        [-84.123098, 45.777668],
#        [-84.207715, 45.750011],
#        [-84.250045, 45.739827999999996],
#        [-84.353121, 45.699397],
#        [-84.375028, 45.694433],
#        [-84.411773, 45.692447],
#        [-84.46427299999999, 45.696954],
#        [-84.51003899999999, 45.709432],
#        [-84.568844, 45.738077],
#        [-84.630764, 45.782886999999995],
#        [-84.685957, 45.804010999999996],
#        [-84.715369, 45.809059999999995],
#        [-84.765541, 45.811295],
#        [-84.942538, 45.842735],
#        [-85.041795, 45.849148],
#        [-85.125069, 45.866386],
#        [-85.57007399999999, 45.883244],
#        [-85.662916, 45.869588],
#        [-85.758969, 45.851166],
#        [-85.80639699999999, 45.839648],
#        [-85.868241, 45.819795],
#        [-85.86396099999999, 46.071995],
#        [-85.865025, 46.244631],
#        [-85.237839, 46.245421]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26097', 'name': 'Mackinac County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.33301, 44.772096999999995],
#        [-85.332634, 44.813049],
#        [-85.324647, 44.818608999999995],
#        [-85.318091, 44.819475],
#        [-85.31638799999999, 44.822454],
#        [-85.321086, 44.827552],
#        [-85.31986599999999, 44.833635],
#        [-85.322887, 44.845600000000005],
#        [-85.327181, 44.848155],
#        [-85.327696, 44.850707],
#        [-85.309679, 44.854313],
#        [-85.291716, 44.859608],
#        [-84.847309, 44.858036999999996],
#        [-84.847353, 44.771223],
#        [-84.84972599999999, 44.685165999999995],
#        [-84.850929, 44.511069],
#        [-85.092947, 44.510461],
#        [-85.334, 44.512302999999996],
#        [-85.332861, 44.603725999999995],
#        [-85.33301, 44.772096999999995]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26079', 'name': 'Kalkaska County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-86.27191499999999, 43.118365],
#        [-85.90743499999999, 43.118911],
#        [-85.908388, 43.20592],
#        [-85.790662, 43.205166999999996],
#        [-85.78850299999999, 43.030877],
#        [-85.782195, 42.913364],
#        [-85.78249799999999, 42.7682],
#        [-87.05871599999999, 42.765201999999995],
#        [-87.107669, 43.118243],
#        [-86.27191499999999, 43.118365]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26139', 'name': 'Ottawa County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.608644, 44.511342],
#        [-84.46823599999999, 44.510808999999995],
#        [-84.370643, 44.507222999999996],
#        [-84.368631, 44.247071999999996],
#        [-84.367995, 44.20381],
#        [-84.36632399999999, 44.175508],
#        [-84.368039, 44.160537999999995],
#        [-84.851705, 44.161375],
#        [-84.85318, 44.248242999999995],
#        [-84.852857, 44.291433],
#        [-84.85564699999999, 44.378948],
#        [-84.855795, 44.421983999999995],
#        [-84.850929, 44.511069],
#        [-84.608644, 44.511342]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26143', 'name': 'Roscommon County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.290826, 43.481418],
#        [-84.170576, 43.481969],
#        [-84.168127, 43.568898999999995],
#        [-84.05, 43.567324],
#        [-84.05098699999999, 43.524063999999996],
#        [-83.817228, 43.522345],
#        [-83.817678, 43.479051999999996],
#        [-83.698816, 43.478957],
#        [-83.69838899999999, 43.326448],
#        [-83.695258, 43.326048],
#        [-83.695621, 43.221422],
#        [-83.932071, 43.220377],
#        [-83.929079, 43.132782],
#        [-84.050388, 43.131709],
#        [-84.168044, 43.128633],
#        [-84.367891, 43.128451999999996],
#        [-84.369777, 43.481573],
#        [-84.290826, 43.481418]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26145', 'name': 'Saginaw County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.007246, 44.508860999999996],
#        [-83.886634, 44.508973],
#        [-83.88356, 44.392471],
#        [-83.883977, 44.161786],
#        [-84.22547899999999, 44.161747999999996],
#        [-84.368039, 44.160537999999995],
#        [-84.36632399999999, 44.175508],
#        [-84.367995, 44.20381],
#        [-84.368631, 44.247071999999996],
#        [-84.370643, 44.507222999999996],
#        [-84.007246, 44.508860999999996]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26129', 'name': 'Ogemaw County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.235547, 43.671884999999996],
#        [-83.11784399999999, 43.675492999999996],
#        [-83.10861, 43.479203],
#        [-83.103826, 43.327365],
#        [-83.354418, 43.322257],
#        [-83.351709, 43.235192999999995],
#        [-83.460708, 43.232791],
#        [-83.46073299999999, 43.223130999999995],
#        [-83.695621, 43.221422],
#        [-83.695258, 43.326048],
#        [-83.69838899999999, 43.326448],
#        [-83.69920599999999, 43.597392],
#        [-83.703198, 43.673218999999996],
#        [-83.708317, 43.828720999999994],
#        [-83.46740299999999, 43.728908999999994],
#        [-83.46659199999999, 43.667621],
#        [-83.235547, 43.671884999999996]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26157', 'name': 'Tuscola County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-86.158332, 43.816129],
#        [-86.398011, 43.819418],
#        [-87.00008, 43.82358],
#        [-87.00008, 43.820966999999996],
#        [-87.093109, 43.820113],
#        [-87.048847, 44],
#        [-87.046249, 44],
#        [-87.013234, 44.131904999999996],
#        [-87.000073, 44.163236],
#        [-87.00008, 44.154821],
#        [-86.98799799999999, 44.182649],
#        [-86.625019, 44.181563999999995],
#        [-86.37754, 44.178613999999996],
#        [-86.04198799999999, 44.167091],
#        [-86.03929699999999, 44.049400000000006],
#        [-86.04048, 44.000008],
#        [-86.03788399999999, 43.815611],
#        [-86.158332, 43.816129]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26105', 'name': 'Mason County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.60186399999999, 42.769873],
#        [-84.36366, 42.769971],
#        [-84.363659, 42.775777999999995],
#        [-84.158189, 42.776638999999996],
#        [-84.151354, 42.702245],
#        [-84.14174799999999, 42.547264999999996],
#        [-84.14060099999999, 42.508393999999996],
#        [-84.14071299999999, 42.424611],
#        [-84.36480499999999, 42.424693999999995],
#        [-84.364783, 42.422146999999995],
#        [-84.600403, 42.421983999999995],
#        [-84.602949, 42.640243],
#        [-84.602761, 42.76988],
#        [-84.60186399999999, 42.769873]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26065', 'name': 'Ingham County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-89.365312, 46.419275],
#        [-89.365347, 46.505645],
#        [-89.74145999999999, 46.505247],
#        [-89.74025999999999, 46.592147],
#        [-89.864481, 46.592765],
#        [-89.862765, 46.765344],
#        [-90.000171, 46.765529],
#        [-90.00016099999999, 46.999936999999996],
#        [-90.111689, 47.041964],
#        [-90.00014499999999, 47.214968999999996],
#        [-89.95710199999999, 47.291103],
#        [-89.68073, 47.714552],
#        [-89.000109, 47.499913],
#        [-88.948869, 47.477145],
#        [-88.933303, 47.031256],
#        [-88.93248, 46.764787],
#        [-88.863906, 46.765012999999996],
#        [-88.864474, 46.679244999999995],
#        [-88.98952899999999, 46.680119],
#        [-88.990588, 46.333251],
#        [-89.365408, 46.332963],
#        [-89.365312, 46.419275]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26131', 'name': 'Ontonagon County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.29292799999999, 41.98482],
#        [-85.29362599999999, 42.071553],
#        [-85.06038699999999, 42.072855],
#        [-84.82649099999999, 42.072468],
#        [-84.825069, 41.897911],
#        [-84.82513, 41.759999],
#        [-85.29217899999999, 41.759889],
#        [-85.29292799999999, 41.98482]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26023', 'name': 'Branch County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.890439, 45.03047],
#        [-83.88848399999999, 44.856457999999996],
#        [-84.151781, 44.854839],
#        [-84.25232, 44.855748999999996],
#        [-84.371757, 44.855028999999995],
#        [-84.37156, 44.950939999999996],
#        [-84.36795099999999, 45.069883],
#        [-84.366827, 45.198761999999995],
#        [-84.022072, 45.198423999999996],
#        [-83.88121799999999, 45.202062],
#        [-83.880541, 45.188033999999995],
#        [-83.882911, 45.159504999999996],
#        [-83.88067199999999, 45.095045999999996],
#        [-83.880234, 45.030611],
#        [-83.890439, 45.03047]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26119', 'name': 'Montmorency County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.20614599999999, 43.813753999999996],
#        [-85.562439, 43.815633999999996],
#        [-85.563041, 44.053397],
#        [-85.564041, 44.117492],
#        [-85.565105, 44.131378999999995],
#        [-85.564554, 44.164893],
#        [-85.08704, 44.164238999999995],
#        [-85.088477, 43.929096],
#        [-85.087828, 43.857077],
#        [-85.08881099999999, 43.813676],
#        [-85.20614599999999, 43.813753999999996]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26133', 'name': 'Osceola County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.337092, 44.339254],
#        [-85.334777, 44.165118],
#        [-85.821186, 44.164197],
#        [-85.82082199999999, 44.360026999999995],
#        [-85.817802, 44.512969],
#        [-85.334, 44.512302999999996],
#        [-85.335066, 44.476653999999996],
#        [-85.338404, 44.425376],
#        [-85.337092, 44.339254]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26165', 'name': 'Wexford County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.404112, 44.858792],
#        [-82.749945, 44.855543999999995],
#        [-82.749945, 44.857672],
#        [-82.624939, 44.858762999999996],
#        [-82.624939, 44.862766],
#        [-82.499934, 44.864025999999996],
#        [-82.499934, 44.857551],
#        [-82.408717, 44.858146999999995],
#        [-82.382837, 44.750015999999995],
#        [-82.385504, 44.750015999999995],
#        [-82.374927, 44.716437],
#        [-82.374927, 44.708138999999996],
#        [-82.354787, 44.625015],
#        [-82.356455, 44.625015],
#        [-82.32951899999999, 44.512834],
#        [-82.49992999999999, 44.511834],
#        [-82.49992999999999, 44.514921],
#        [-82.74994199999999, 44.511776999999995],
#        [-83.50050499999999, 44.511582999999995],
#        [-83.886634, 44.508973],
#        [-83.88848399999999, 44.856457999999996],
#        [-83.404112, 44.858792]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26001', 'name': 'Alcona County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.771861, 42.76824],
#        [-85.545564, 42.768139],
#        [-85.543191, 42.421433],
#        [-86.01293, 42.418892],
#        [-86.375016, 42.419942],
#        [-86.87476699999999, 42.415413],
#        [-87.04004599999999, 42.416993],
#        [-87.019863, 42.493763],
#        [-87.05871599999999, 42.765201999999995],
#        [-85.771861, 42.76824]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26005', 'name': 'Allegan County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.607734, 43.897659],
#        [-83.18527999999999, 44.168403999999995],
#        [-82.99995299999999, 44.171088999999995],
#        [-82.24991399999999, 44.158750999999995],
#        [-82.145501, 43.695586999999996],
#        [-82.607682, 43.690439],
#        [-83.217451, 43.672318999999995],
#        [-83.46659199999999, 43.667621],
#        [-83.46740299999999, 43.728908999999994],
#        [-83.713563, 43.830898],
#        [-83.607734, 43.897659]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26063', 'name': 'Huron County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.82533699999999, 41.810953999999995],
#        [-84.82649099999999, 42.072468],
#        [-84.709257, 42.070336999999995],
#        [-84.363297, 42.073456],
#        [-84.360416, 41.706589],
#        [-84.718391, 41.698971],
#        [-84.805996, 41.696118],
#        [-84.80588499999999, 41.760171],
#        [-84.82513, 41.759999],
#        [-84.82533699999999, 41.810953999999995]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26059', 'name': 'Hillsdale County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-88.115464, 46.246621],
#        [-87.61591399999999, 46.246794],
#        [-87.61761299999999, 45.898841999999995],
#        [-87.696946, 45.898841999999995],
#        [-87.697971, 45.780623999999996],
#        [-87.697159, 45.722986999999996],
#        [-87.846505, 45.722494999999995],
#        [-87.85548, 45.726943],
#        [-87.86390399999999, 45.736391],
#        [-87.863874, 45.74266],
#        [-87.861665, 45.743722999999996],
#        [-87.862211, 45.745017999999995],
#        [-87.865681, 45.746288],
#        [-87.868111, 45.749477],
#        [-87.873339, 45.750439],
#        [-87.876898, 45.754379],
#        [-87.891911, 45.754065],
#        [-87.89836299999999, 45.752503],
#        [-87.90270699999999, 45.757932],
#        [-87.90666, 45.759524],
#        [-87.91133599999999, 45.756539],
#        [-87.916556, 45.759460999999995],
#        [-87.921994, 45.756996],
#        [-87.929127, 45.760368],
#        [-87.93458299999999, 45.758095999999995],
#        [-87.945478, 45.756687],
#        [-87.95218299999999, 45.758416],
#        [-87.960758, 45.757566],
#        [-87.964546, 45.759040999999996],
#        [-87.963996, 45.760794],
#        [-87.96696999999999, 45.764021],
#        [-87.986429, 45.769596],
#        [-87.989829, 45.772945],
#        [-87.98178899999999, 45.775081],
#        [-87.98087, 45.776976999999995],
#        [-87.98794199999999, 45.793074999999995],
#        [-87.991447, 45.795393],
#        [-87.995876, 45.795435],
#        [-88.007043, 45.792192],
#        [-88.01758799999999, 45.792455],
#        [-88.027232, 45.789197],
#        [-88.039728, 45.789626],
#        [-88.040937, 45.784265],
#        [-88.04996, 45.781192999999995],
#        [-88.07140199999999, 45.779938],
#        [-88.075985, 45.781396],
#        [-88.079976, 45.785123999999996],
#        [-88.094754, 45.785754999999995],
#        [-88.09942, 45.789989999999996],
#        [-88.103213, 45.791255],
#        [-88.106006, 45.797118],
#        [-88.105362, 45.799825],
#        [-88.107608, 45.803039999999996],
#        [-88.116266, 45.804086],
#        [-88.12868, 45.808861],
#        [-88.13198, 45.811549],
#        [-88.136212, 45.818735],
#        [-88.134243, 45.822741],
#        [-88.12090099999999, 45.832961999999995],
#        [-88.10519599999999, 45.842413],
#        [-88.097758, 45.850438],
#        [-88.08771899999999, 45.85695],
#        [-88.082465, 45.864961],
#        [-88.077653, 45.863744],
#        [-88.074828, 45.864905],
#        [-88.07583799999999, 45.86963],
#        [-88.073696, 45.871818999999995],
#        [-88.069763, 45.872938],
#        [-88.08182, 45.880201],
#        [-88.096496, 45.879861],
#        [-88.100914, 45.881772999999995],
#        [-88.10322599999999, 45.894681999999996],
#        [-88.10649099999999, 45.897968],
#        [-88.106894, 45.900749999999995],
#        [-88.105023, 45.906454],
#        [-88.101338, 45.910906999999995],
#        [-88.095314, 45.913657],
#        [-88.095034, 45.915839],
#        [-88.103006, 45.921775],
#        [-88.116845, 45.921627],
#        [-88.117977, 46.130927],
#        [-88.117407, 46.246618],
#        [-88.115464, 46.246621]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26043', 'name': 'Dickinson County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.737686, 46.157896],
#        [-85.112438, 46.158190999999995],
#        [-85.113126, 46.245667],
#        [-85.237839, 46.245421],
#        [-85.240106, 46.521018999999995],
#        [-85.23433, 47.04761],
#        [-84.859335, 46.888843],
#        [-84.762957, 46.634324],
#        [-84.556962, 46.460639],
#        [-84.475594, 46.452864],
#        [-84.445149, 46.489016],
#        [-84.42027399999999, 46.501076999999995],
#        [-84.394725, 46.499241999999995],
#        [-84.37398999999999, 46.509099],
#        [-84.341427, 46.507689],
#        [-84.32537099999999, 46.500021],
#        [-84.293016, 46.492802999999995],
#        [-84.275814, 46.492821],
#        [-84.25443399999999, 46.500820999999995],
#        [-84.226131, 46.533919999999995],
#        [-84.19402, 46.540149],
#        [-84.17742799999999, 46.52692],
#        [-84.139426, 46.532219],
#        [-84.128925, 46.530119],
#        [-84.11122499999999, 46.504118999999996],
#        [-84.14617199999999, 46.41852],
#        [-84.13890599999999, 46.372220999999996],
#        [-84.11912199999999, 46.337013999999996],
#        [-84.106247, 46.321963],
#        [-84.11962899999999, 46.315013],
#        [-84.115563, 46.268225],
#        [-84.097766, 46.256512],
#        [-84.10808899999999, 46.241237999999996],
#        [-84.085785, 46.209990999999995],
#        [-84.077027, 46.187557999999996],
#        [-84.005685, 46.149550999999995],
#        [-84.005873, 46.118469],
#        [-83.976134, 46.102554],
#        [-83.955424, 46.057188],
#        [-83.903474, 46.06091],
#        [-83.82624299999999, 46.119288],
#        [-83.759529, 46.103173],
#        [-83.654647, 46.122054999999996],
#        [-83.571467, 46.105998],
#        [-83.43355799999999, 45.998895],
#        [-83.636867, 45.773944],
#        [-84.123098, 45.777668],
#        [-84.11418499999999, 45.985216],
#        [-84.239313, 45.98488],
#        [-84.23883599999999, 46.071456999999995],
#        [-84.36309, 46.071580999999995],
#        [-84.363503, 46.157984],
#        [-84.737686, 46.157896]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26033', 'name': 'Chippewa County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.641078, 44.775068999999995],
#        [-85.815293, 44.774522],
#        [-85.931685, 44.778279],
#        [-86.12509399999999, 44.778631],
#        [-86.734529, 44.773074],
#        [-86.68628799999999, 44.881001999999995],
#        [-86.49992999999999, 45.0808],
#        [-86.433128, 45.124991],
#        [-86.24954799999999, 45.236125],
#        [-86.46412, 45.32481],
#        [-86.460797, 45.584433],
#        [-86.000095, 45.582398999999995],
#        [-85.855768, 45.578385999999995],
#        [-85.786591, 45.562926999999995],
#        [-85.736133, 45.541908],
#        [-85.67952799999999, 45.506980999999996],
#        [-85.62507599999999, 45.454602],
#        [-85.558497, 45.375001999999995],
#        [-85.475966, 45.264005],
#        [-85.462864, 45.229323],
#        [-85.45853699999999, 45.196456999999995],
#        [-85.468857, 45.130714],
#        [-85.550455, 45.051072999999995],
#        [-85.55698199999999, 45.017585],
#        [-85.560999, 44.955407],
#        [-85.570494, 44.930142],
#        [-85.594725, 44.901089999999996],
#        [-85.591448, 44.874964],
#        [-85.614305, 44.826755999999996],
#        [-85.60963799999999, 44.799154],
#        [-85.612318, 44.785381],
#        [-85.618033, 44.774557],
#        [-85.641078, 44.775068999999995]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26089', 'name': 'Leelanau County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.08787099999999, 43.987243],
#        [-85.08704, 44.164238999999995],
#        [-84.890063, 44.161252],
#        [-84.608104, 44.160481999999995],
#        [-84.606685, 44.105422],
#        [-84.60603499999999, 43.815218],
#        [-85.08881099999999, 43.813676],
#        [-85.087828, 43.857077],
#        [-85.08787099999999, 43.987243]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26035', 'name': 'Clare County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-88.365808, 46.419959],
#        [-88.67939199999999, 46.420139],
#        [-88.678427, 46.722653],
#        [-88.67607199999999, 46.730056],
#        [-88.67625699999999, 46.764789],
#        [-88.67915599999999, 46.764978],
#        [-88.678983, 46.851822],
#        [-88.551943, 46.851794999999996],
#        [-88.552185, 46.938533],
#        [-88.449484, 46.939257],
#        [-88.221352, 46.999925],
#        [-88.043731, 47.043957999999996],
#        [-88.044709, 46.765353],
#        [-87.991389, 46.765159],
#        [-87.991546, 46.679113],
#        [-88.115843, 46.678380999999995],
#        [-88.116571, 46.419951],
#        [-88.365808, 46.419959]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26013', 'name': 'Baraga County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.880849, 45.202072],
#        [-83.513882, 45.207122999999996],
#        [-82.99995899999999, 45.206409],
#        [-82.99995899999999, 45.20787],
#        [-82.74994799999999, 45.212247999999995],
#        [-82.74994799999999, 45.20984],
#        [-82.62494199999999, 45.210597],
#        [-82.62494199999999, 45.212778],
#        [-82.499937, 45.211476],
#        [-82.499937, 45.208224],
#        [-82.490596, 45.208484],
#        [-82.408717, 44.858146999999995],
#        [-82.499934, 44.857551],
#        [-82.499934, 44.864025999999996],
#        [-82.624939, 44.862766],
#        [-82.624939, 44.858762999999996],
#        [-82.749945, 44.857672],
#        [-82.749945, 44.855543999999995],
#        [-83.526107, 44.859539],
#        [-83.88848399999999, 44.856457999999996],
#        [-83.890439, 45.03047],
#        [-83.880234, 45.030611],
#        [-83.882911, 45.159504999999996],
#        [-83.880849, 45.202072]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26007', 'name': 'Alpena County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.845005, 43.379177],
#        [-84.845962, 43.466158],
#        [-84.36987599999999, 43.466044],
#        [-84.367795, 43.117937999999995],
#        [-84.60052499999999, 43.117714],
#        [-84.836889, 43.118851],
#        [-84.83530499999999, 43.2922],
#        [-84.845573, 43.292231],
#        [-84.845005, 43.379177]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26057', 'name': 'Gratiot County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.420761, 42.093568],
#        [-83.420622, 42.087776999999996],
#        [-83.539396, 42.085598],
#        [-83.54435099999999, 42.239537999999996],
#        [-83.544203, 42.276894],
#        [-83.551907, 42.435165999999995],
#        [-83.343621, 42.441401],
#        [-82.966093, 42.449886],
#        [-82.74990799999999, 42.451091999999996],
#        [-82.83024999999999, 42.373492],
#        [-82.94548499999999, 42.347395999999996],
#        [-82.95975, 42.340033],
#        [-82.98919699999999, 42.332481],
#        [-83.014076, 42.331320999999996],
#        [-83.026234, 42.32891],
#        [-83.063637, 42.316857],
#        [-83.08001999999999, 42.307172],
#        [-83.097704, 42.289674999999995],
#        [-83.11202999999999, 42.260587],
#        [-83.126361, 42.238412],
#        [-83.127237, 42.234761999999996],
#        [-83.134384, 42.174620999999995],
#        [-83.125304, 42.137556],
#        [-83.11922799999999, 42.125263],
#        [-83.122401, 42.114269],
#        [-83.127526, 42.104968],
#        [-83.13212299999999, 42.088139],
#        [-83.145691, 42.053858],
#        [-83.14945, 42.040264],
#        [-83.143956, 42.02793],
#        [-83.18457599999999, 42.028506],
#        [-83.190317, 42.032457],
#        [-83.19734299999999, 42.034101],
#        [-83.199756, 42.035241],
#        [-83.201544, 42.039314999999995],
#        [-83.209519, 42.04027],
#        [-83.21684599999999, 42.04409],
#        [-83.219674, 42.049119999999995],
#        [-83.230254, 42.048733999999996],
#        [-83.228811, 42.054566],
#        [-83.23208199999999, 42.055333999999995],
#        [-83.234286, 42.059287999999995],
#        [-83.236615, 42.058240999999995],
#        [-83.243675, 42.061923],
#        [-83.248618, 42.060713],
#        [-83.250222, 42.063932],
#        [-83.254728, 42.0643],
#        [-83.25147899999999, 42.067946],
#        [-83.254502, 42.068211],
#        [-83.257978, 42.073975999999995],
#        [-83.26247699999999, 42.073025],
#        [-83.265039, 42.06917],
#        [-83.267372, 42.069099],
#        [-83.269476, 42.071342],
#        [-83.26921899999999, 42.075423],
#        [-83.276994, 42.076328],
#        [-83.274833, 42.080346],
#        [-83.27798399999999, 42.079342],
#        [-83.279917, 42.080283],
#        [-83.280208, 42.081722],
#        [-83.27698699999999, 42.082419],
#        [-83.282274, 42.083929],
#        [-83.28018399999999, 42.085846],
#        [-83.283017, 42.085817999999996],
#        [-83.283165, 42.089470999999996],
#        [-83.284978, 42.089731],
#        [-83.284041, 42.088834999999996],
#        [-83.285141, 42.087748999999995],
#        [-83.287235, 42.088243999999996],
#        [-83.28586299999999, 42.090889],
#        [-83.288521, 42.089825],
#        [-83.294814, 42.094378],
#        [-83.420761, 42.093568]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26163', 'name': 'Wayne County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.24434, 44.855519],
#        [-84.151781, 44.854839],
#        [-83.88848399999999, 44.856457999999996],
#        [-83.888367, 44.692347999999996],
#        [-83.886634, 44.508973],
#        [-84.370643, 44.507222999999996],
#        [-84.37211599999999, 44.726158],
#        [-84.371757, 44.855028999999995],
#        [-84.24434, 44.855519]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26135', 'name': 'Oscoda County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.817228, 43.522345],
#        [-84.05098699999999, 43.524063999999996],
#        [-84.05, 43.567324],
#        [-84.168127, 43.568898999999995],
#        [-84.16693099999999, 43.698018999999995],
#        [-84.167318, 43.825902],
#        [-84.165904, 43.9122],
#        [-84.166377, 43.996901],
#        [-84.04540899999999, 43.996973999999994],
#        [-84.044843, 43.911145999999995],
#        [-83.907608, 43.910415],
#        [-83.874999, 43.900053],
#        [-83.708525, 43.833948],
#        [-83.713563, 43.830898],
#        [-83.708317, 43.828720999999994],
#        [-83.703198, 43.673218999999996],
#        [-83.69920599999999, 43.597392],
#        [-83.698816, 43.478957],
#        [-83.817678, 43.479051999999996],
#        [-83.817228, 43.522345]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26017', 'name': 'Bay County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-86.38461699999999, 43.472255],
#        [-86.039491, 43.467447],
#        [-86.03895299999999, 43.293518999999996],
#        [-85.790448, 43.293003],
#        [-85.790662, 43.205166999999996],
#        [-85.908388, 43.20592],
#        [-85.90743499999999, 43.118911],
#        [-86.146166, 43.117394999999995],
#        [-86.375058, 43.119056],
#        [-87.107669, 43.118243],
#        [-87.147166, 43.379858999999996],
#        [-87.14033099999999, 43.471436],
#        [-86.87507599999999, 43.473689],
#        [-86.38461699999999, 43.472255]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26121', 'name': 'Muskegon County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-89.65744699999999, 47.749896],
#        [-89.483385, 48.013715999999995],
#        [-89.33755, 47.974261],
#        [-88.677442, 48.245397],
#        [-88.369862, 48.306062999999995],
#        [-88.00007699999999, 48.164049999999996],
#        [-88.000078, 48.155882999999996],
#        [-87.87508199999999, 48.114726],
#        [-87.750087, 48.063877999999995],
#        [-87.625091, 48.021108999999996],
#        [-87.500095, 47.968114],
#        [-87.112695, 47.817997999999996],
#        [-87.11211399999999, 47.223268999999995],
#        [-88.04661399999999, 47.218696],
#        [-88.04606299999999, 47.199722],
#        [-88.298436, 47.199782],
#        [-88.298992, 47.286097],
#        [-88.512592, 47.285942999999996],
#        [-89.000109, 47.499913],
#        [-89.68073, 47.714552],
#        [-89.65744699999999, 47.749896]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26083', 'name': 'Keweenaw County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-88.991089, 46.57859],
#        [-88.98952899999999, 46.680119],
#        [-88.864474, 46.679244999999995],
#        [-88.863906, 46.765012999999996],
#        [-88.93248, 46.764787],
#        [-88.933303, 47.031256],
#        [-88.948869, 47.477145],
#        [-88.512592, 47.285942999999996],
#        [-88.298992, 47.286097],
#        [-88.298436, 47.199782],
#        [-88.04606299999999, 47.199722],
#        [-88.043731, 47.043957999999996],
#        [-88.221352, 46.999925],
#        [-88.449484, 46.939257],
#        [-88.552185, 46.938533],
#        [-88.551943, 46.851794999999996],
#        [-88.678983, 46.851822],
#        [-88.67915599999999, 46.764978],
#        [-88.67625699999999, 46.764789],
#        [-88.67607199999999, 46.730056],
#        [-88.678427, 46.722653],
#        [-88.67939199999999, 46.420139],
#        [-88.991236, 46.419703999999996],
#        [-88.991089, 46.57859]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26061', 'name': 'Houghton County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-86.107885, 42.070802],
#        [-85.76294299999999, 42.069327],
#        [-85.760117, 41.896615],
#        [-85.76018599999999, 41.798814],
#        [-85.763359, 41.796487],
#        [-85.7626, 41.793154],
#        [-85.76634399999999, 41.791509],
#        [-85.76942, 41.784672],
#        [-85.786389, 41.776652999999996],
#        [-85.785879, 41.773309],
#        [-85.78733299999999, 41.77088],
#        [-85.78738, 41.76845],
#        [-85.790374, 41.765924],
#        [-85.785888, 41.763400000000004],
#        [-85.784424, 41.761254],
#        [-85.784601, 41.759737],
#        [-85.78576, 41.759330999999996],
#        [-85.790525, 41.761238999999996],
#        [-85.791837, 41.759979],
#        [-85.79133499999999, 41.759077999999995],
#        [-85.792622, 41.759068],
#        [-86.08840599999999, 41.760638],
#        [-86.226095, 41.760405999999996],
#        [-86.22329099999999, 41.913208],
#        [-86.22294, 42.071484],
#        [-86.107885, 42.070802]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26027', 'name': 'Cass County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.61063299999999, 44.51135],
#        [-84.850929, 44.511069],
#        [-84.84972599999999, 44.685165999999995],
#        [-84.847353, 44.771223],
#        [-84.847309, 44.858036999999996],
#        [-84.52651999999999, 44.857386999999996],
#        [-84.371757, 44.855028999999995],
#        [-84.37211599999999, 44.726158],
#        [-84.370643, 44.507222999999996],
#        [-84.46823599999999, 44.510808999999995],
#        [-84.61063299999999, 44.51135]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26039', 'name': 'Crawford County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.92000399999999, 43.29316],
#        [-86.03895299999999, 43.293518999999996],
#        [-86.03978, 43.554182],
#        [-86.039304, 43.735535],
#        [-86.03788399999999, 43.815611],
#        [-85.854976, 43.814049999999995],
#        [-85.562439, 43.815633999999996],
#        [-85.56253799999999, 43.294270999999995],
#        [-85.92000399999999, 43.29316]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26123', 'name': 'Newaygo County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.167181, 43.63748],
#        [-84.170576, 43.481969],
#        [-84.369777, 43.481573],
#        [-84.36987599999999, 43.466044],
#        [-84.60754, 43.466006],
#        [-84.60810599999999, 43.626675999999996],
#        [-84.60603499999999, 43.815218],
#        [-84.366676, 43.813559999999995],
#        [-84.366511, 43.828434],
#        [-84.167318, 43.825902],
#        [-84.167181, 43.63748]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26111', 'name': 'Midland County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.59492999999999, 44.160509999999995],
#        [-84.375607, 44.160298],
#        [-84.166107, 44.161788],
#        [-84.166744, 44.112261],
#        [-84.165904, 43.9122],
#        [-84.167318, 43.825902],
#        [-84.366511, 43.828434],
#        [-84.366676, 43.813559999999995],
#        [-84.60603499999999, 43.815218],
#        [-84.606685, 44.105422],
#        [-84.608104, 44.160481999999995],
#        [-84.59492999999999, 44.160509999999995]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26051', 'name': 'Gladwin County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.787247, 42.428591],
#        [-83.765078, 42.429364],
#        [-83.743239, 42.428484999999995],
#        [-83.551907, 42.435165999999995],
#        [-83.544203, 42.276894],
#        [-83.54435099999999, 42.239537999999996],
#        [-83.539396, 42.085598],
#        [-83.700138, 42.083942],
#        [-84.008337, 42.078005],
#        [-84.008152, 42.073598],
#        [-84.131963, 42.071577],
#        [-84.13406499999999, 42.169250999999996],
#        [-84.130771, 42.250035],
#        [-84.131136, 42.424566999999996],
#        [-83.94465, 42.424149],
#        [-83.787247, 42.428591]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26161', 'name': 'Washtenaw County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.411518, 43.814602],
#        [-85.08881099999999, 43.813676],
#        [-85.08499599999999, 43.46619],
#        [-85.370567, 43.468308],
#        [-85.562392, 43.468247],
#        [-85.562439, 43.815633999999996],
#        [-85.411518, 43.814602]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26107', 'name': 'Mecosta County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.750143, 47.261387],
#        [-85.750143, 47.264283],
#        [-85.722212, 47.249984999999995],
#        [-85.25011099999999, 47.05654],
#        [-85.25011099999999, 47.054513],
#        [-85.23433, 47.04761],
#        [-85.240106, 46.521018999999995],
#        [-85.237839, 46.245421],
#        [-85.865025, 46.244631],
#        [-85.864723, 46.678951],
#        [-85.860513, 46.999983],
#        [-85.859054, 46.999983],
#        [-85.854607, 47.249977],
#        [-85.858727, 47.249976],
#        [-85.854862, 47.305482],
#        [-85.750143, 47.261387]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26095', 'name': 'Luce County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-86.39793399999999, 43.819417],
#        [-86.03788399999999, 43.815611],
#        [-86.039491, 43.467447],
#        [-86.39714099999999, 43.472487],
#        [-86.87507599999999, 43.473689],
#        [-87.14033099999999, 43.471436],
#        [-87.125079, 43.670445],
#        [-87.114102, 43.734111],
#        [-87.093109, 43.820113],
#        [-87.00008, 43.820966999999996],
#        [-87.00008, 43.82358],
#        [-86.39793399999999, 43.819417]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26127', 'name': 'Oceana County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.71149299999999, 42.159338999999996],
#        [-84.716949, 42.246918],
#        [-84.71860199999999, 42.334534999999995],
#        [-84.718493, 42.42152],
#        [-84.364783, 42.422146999999995],
#        [-84.36480499999999, 42.424693999999995],
#        [-84.131136, 42.424566999999996],
#        [-84.130771, 42.250035],
#        [-84.13406499999999, 42.169250999999996],
#        [-84.131963, 42.071577],
#        [-84.179835, 42.073791],
#        [-84.363297, 42.073456],
#        [-84.709378, 42.070339],
#        [-84.71149299999999, 42.159338999999996]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26075', 'name': 'Jackson County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.845005, 43.379177],
#        [-84.845573, 43.292231],
#        [-84.83530499999999, 43.2922],
#        [-84.836889, 43.118851],
#        [-85.07503299999999, 43.120213],
#        [-85.312513, 43.118793],
#        [-85.312376, 43.294205],
#        [-85.56253799999999, 43.294270999999995],
#        [-85.562392, 43.468247],
#        [-84.845962, 43.466158],
#        [-84.845005, 43.379177]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26117', 'name': 'Montcalm County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.109506, 43.501084999999996],
#        [-83.11784399999999, 43.675492999999996],
#        [-82.607682, 43.690439],
#        [-82.145501, 43.695586999999996],
#        [-82.12297099999999, 43.590827],
#        [-82.33407299999999, 43.170412999999996],
#        [-82.503163, 43.168946],
#        [-82.996257, 43.154098999999995],
#        [-83.00043, 43.284912999999996],
#        [-83.119027, 43.28368],
#        [-83.120396, 43.327048999999995],
#        [-83.103826, 43.327365],
#        [-83.109506, 43.501084999999996]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26151', 'name': 'Sanilac County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.364803, 42.893626999999995],
#        [-84.367378, 43.038264],
#        [-84.367891, 43.128451999999996],
#        [-84.168044, 43.128633],
#        [-84.050388, 43.131709],
#        [-83.929079, 43.132782],
#        [-83.928384, 43.027847],
#        [-83.928837, 42.956548],
# ...
#        [-84.852857, 44.291433],
#        [-84.85318, 44.248242999999995],
#        [-84.851705, 44.161375],
#        [-84.972504, 44.162475]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26113', 'name': 'Missaukee County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.086882, 42.534791999999996],
#        [-83.09396199999999, 42.673708999999995],
#        [-83.096032, 42.741473],
#        [-83.098354, 42.776286],
#        [-83.102891, 42.888647],
#        [-83.023573, 42.890543],
#        [-82.994579, 42.893522],
#        [-82.792845, 42.895837],
#        [-82.73901, 42.897541],
#        [-82.729277, 42.706058999999996],
#        [-82.719664, 42.703041999999996],
#        [-82.723317, 42.700441],
#        [-82.70596599999999, 42.68631],
#        [-82.708254, 42.684162],
#        [-82.70617, 42.680870999999996],
#        [-82.70788499999999, 42.675497],
#        [-82.726049, 42.625032999999995],
#        [-82.72317, 42.477778],
#        [-82.74990799999999, 42.451091999999996],
#        [-82.929564, 42.450609],
#        [-83.083393, 42.447153],
#        [-83.086882, 42.534791999999996]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26099', 'name': 'Macomb County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-88.990588, 46.333251],
#        [-88.991236, 46.419703999999996],
#        [-88.116571, 46.419951],
#        [-88.117977, 46.130927],
#        [-88.116845, 45.921627],
#        [-88.126654, 45.921791],
#        [-88.126808, 45.925993999999996],
#        [-88.14125, 45.930844],
#        [-88.146334, 45.934069],
#        [-88.14571099999999, 45.936243],
#        [-88.147651, 45.937427],
#        [-88.155639, 45.937352],
#        [-88.161761, 45.940740999999996],
#        [-88.16385799999999, 45.938381],
#        [-88.17008899999999, 45.939492],
#        [-88.178041, 45.947092999999995],
#        [-88.192058, 45.952650999999996],
#        [-88.19776, 45.953019],
#        [-88.203797, 45.947941],
#        [-88.237106, 45.948277999999995],
#        [-88.244833, 45.952864],
#        [-88.246894, 45.963532],
#        [-88.25497999999999, 45.963511999999994],
#        [-88.25902599999999, 45.959649999999996],
#        [-88.269307, 45.956272],
#        [-88.285314, 45.955262],
#        [-88.293849, 45.950941],
#        [-88.301378, 45.956458999999995],
#        [-88.31302099999999, 45.959430999999995],
#        [-88.320308, 45.963657],
#        [-88.320244, 45.960083999999995],
#        [-88.327276, 45.954957],
#        [-88.33017199999999, 45.956632],
#        [-88.32787599999999, 45.958915],
#        [-88.328041, 45.963539],
#        [-88.33027799999999, 45.965835],
#        [-88.33474, 45.968627],
#        [-88.342036, 45.968984],
#        [-88.342523, 45.971987],
#        [-88.345417, 45.973985],
#        [-88.359821, 45.981891999999995],
#        [-88.371758, 45.985447],
#        [-88.374298, 45.98905],
#        [-88.38050299999999, 45.991765],
#        [-88.38484199999999, 45.990449],
#        [-88.38426, 45.9879],
#        [-88.388644, 45.982623],
#        [-88.395421, 45.980312],
#        [-88.40310099999999, 45.981193],
#        [-88.40991, 45.97967],
#        [-88.416381, 45.975092],
#        [-88.42303799999999, 45.978397],
#        [-88.423193, 45.981725],
#        [-88.426131, 45.984386],
#        [-88.433557, 45.985409],
#        [-88.43476199999999, 45.98834],
#        [-88.438558, 45.988603999999995],
#        [-88.440749, 45.990849999999995],
#        [-88.450037, 45.990111999999996],
#        [-88.454235, 45.993476],
#        [-88.454109, 45.997529],
#        [-88.45867199999999, 45.999514],
#        [-88.470772, 46.000997999999996],
#        [-88.474583, 45.998953],
#        [-88.473771, 45.994907],
#        [-88.475206, 45.993128999999996],
#        [-88.48935499999999, 45.991367],
#        [-88.49797799999999, 45.995794],
#        [-88.49685199999999, 45.999234],
#        [-88.500885, 46.000603999999996],
#        [-88.502286, 46.006971],
#        [-88.506551, 46.011303],
#        [-88.50636399999999, 46.01761],
#        [-88.514692, 46.020019],
#        [-88.533686, 46.02115],
#        [-88.532522, 46.018370999999995],
#        [-88.53626799999999, 46.017688],
#        [-88.53943199999999, 46.014469999999996],
#        [-88.549151, 46.012884],
#        [-88.565663, 46.015679],
#        [-88.571759, 46.013774],
#        [-88.580919, 46.006785],
#        [-88.58827, 46.005098],
#        [-88.592891, 46.011125],
#        [-88.593548, 46.01477],
#        [-88.60117799999999, 46.01777],
#        [-88.607271, 46.011353],
#        [-88.607311, 46.007621],
#        [-88.612712, 46.004462],
#        [-88.61184899999999, 45.99839],
#        [-88.615968, 45.993539],
#        [-88.61300399999999, 45.990977],
#        [-88.615957, 45.987896],
#        [-88.633938, 45.988169],
#        [-88.635201, 45.985217],
#        [-88.63854599999999, 45.985060999999995],
#        [-88.64760199999999, 45.988641],
#        [-88.670827, 45.988547],
#        [-88.663483, 45.992702],
#        [-88.667002, 45.993716],
#        [-88.66672799999999, 45.996932],
#        [-88.67100599999999, 45.998832],
#        [-88.67121499999999, 46.004858999999996],
#        [-88.675916, 46.008545999999996],
#        [-88.67528399999999, 46.011396],
#        [-88.678868, 46.013594999999995],
#        [-88.689696, 46.014002999999995],
#        [-88.703711, 46.018293],
#        [-88.707715, 46.015395999999996],
#        [-88.71207799999999, 46.016346],
#        [-88.712977, 46.012718],
#        [-88.71831399999999, 46.013182],
#        [-88.718024, 46.015611],
#        [-88.722217, 46.01753],
#        [-88.721261, 46.022220999999995],
#        [-88.730475, 46.026728],
#        [-88.734234, 46.025545],
#        [-88.73898, 46.027459],
#        [-88.75272, 46.023415],
#        [-88.758968, 46.019633],
#        [-88.76639899999999, 46.024882],
#        [-88.77062099999999, 46.025560999999996],
#        [-88.76884799999999, 46.021887],
#        [-88.769801, 46.018944],
#        [-88.78015599999999, 46.015395],
#        [-88.782473, 46.016751],
#        [-88.78394, 46.023844],
#        [-88.778734, 46.028875],
#        [-88.778739, 46.03169],
#        [-88.784596, 46.032654],
#        [-88.788766, 46.028622999999996],
#        [-88.796182, 46.033712],
#        [-88.80067, 46.030035999999996],
#        [-88.79624199999999, 46.026854],
#        [-88.79646, 46.023606],
#        [-88.816026, 46.020585999999994],
#        [-88.81544, 46.022974],
#        [-88.81908399999999, 46.026314],
#        [-88.839091, 46.029976],
#        [-88.850822, 46.040312],
#        [-88.989995, 46.096970999999996],
#        [-88.990588, 46.333251]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26071', 'name': 'Iron County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.24721799999999, 42.073263999999995],
#        [-84.179835, 42.073791],
#        [-84.131963, 42.071577],
#        [-84.01086, 42.073513],
#        [-84.008152, 42.073598],
#        [-84.008337, 42.078005],
#        [-83.773922, 42.082429999999995],
#        [-83.769099, 41.875392],
#        [-83.76315, 41.723546],
#        [-84.360416, 41.706589],
#        [-84.363297, 42.073456],
#        [-84.24721799999999, 42.073263999999995]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26091', 'name': 'Lenawee County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.311388, 42.856955],
#        [-85.312513, 43.118793],
#        [-85.07503299999999, 43.120213],
#        [-84.836889, 43.118851],
#        [-84.83762, 43.032641],
#        [-84.837085, 42.770478999999995],
#        [-85.309626, 42.769878],
#        [-85.311388, 42.856955]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26067', 'name': 'Ionia County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.927493, 44.161834],
#        [-83.60083999999999, 44.162929],
#        [-83.18527999999999, 44.168403999999995],
#        [-83.449608, 44.000012],
#        [-83.52614299999999, 43.948620999999996],
#        [-83.708525, 43.833948],
#        [-83.874999, 43.900053],
#        [-83.907608, 43.910415],
#        [-84.044843, 43.911145999999995],
#        [-84.04540899999999, 43.996973999999994],
#        [-84.166377, 43.996901],
#        [-84.166107, 44.161788],
#        [-83.927493, 44.161834]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26011', 'name': 'Arenac County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.94223099999999, 42.072570999999996],
#        [-85.29362599999999, 42.071553],
#        [-85.29947399999999, 42.419639],
#        [-84.99976699999999, 42.422022],
#        [-84.718493, 42.42152],
#        [-84.71860199999999, 42.334534999999995],
#        [-84.716949, 42.246918],
#        [-84.711181, 42.15236],
#        [-84.70955599999999, 42.070366],
#        [-84.82649099999999, 42.072468],
#        [-84.94223099999999, 42.072570999999996]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26025', 'name': 'Calhoun County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.7198, 42.770241999999996],
#        [-84.837085, 42.770478999999995],
#        [-84.83762, 43.032641],
#        [-84.836889, 43.118851],
#        [-84.60052499999999, 43.117714],
#        [-84.367795, 43.117937999999995],
#        [-84.36366, 42.769971],
#        [-84.7198, 42.770241999999996]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26037', 'name': 'Clinton County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.204263, 45.626247],
#        [-84.201062, 45.752275],
#        [-84.123098, 45.777668],
#        [-83.48397399999999, 45.771937],
#        [-82.999963, 45.556377999999995],
#        [-82.874956, 45.496722999999996],
#        [-82.74995, 45.442220999999996],
#        [-82.52064, 45.335902],
#        [-82.490596, 45.208484],
#        [-82.499937, 45.208224],
#        [-82.499937, 45.211476],
#        [-82.62494199999999, 45.212778],
#        [-82.62494199999999, 45.210597],
#        [-82.74994799999999, 45.20984],
#        [-82.74994799999999, 45.212247999999995],
#        [-82.99995899999999, 45.206409],
#        [-83.513882, 45.207122999999996],
#        [-83.752096, 45.205037999999995],
#        [-84.022072, 45.198423999999996],
#        [-84.246634, 45.198718],
#        [-84.246613, 45.282073],
#        [-84.24938, 45.282073],
#        [-84.24750999999999, 45.430872],
#        [-84.25202, 45.625997999999996],
#        [-84.204263, 45.626247]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26141', 'name': 'Presque Isle County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-85.21820000000001, 45.794171999999996],
#        [-85.2244, 45.776869],
#        [-85.276417, 45.697641],
#        [-85.297538, 45.655181],
#        [-85.30758399999999, 45.625006],
#        [-85.308494, 45.610875],
#        [-85.30630699999999, 45.593889],
#        [-85.301358, 45.580483],
#        [-85.283238, 45.550208999999995],
#        [-85.207832, 45.500008],
#        [-85.102278, 45.397448999999995],
#        [-85.098451, 45.39007],
#        [-85.095732, 45.375071],
#        [-85.096533, 45.335743],
#        [-85.04596699999999, 45.334655],
#        [-85.03917299999999, 45.328795],
#        [-85.035786, 45.320769999999996],
#        [-85.02283899999999, 45.310089],
#        [-85.015005, 45.295846999999995],
#        [-85.018894, 45.28957],
#        [-85.01276899999999, 45.279658999999995],
#        [-85.003014, 45.27279],
#        [-84.988248, 45.274695],
#        [-84.965066, 45.271221999999995],
#        [-84.967316, 45.281499],
#        [-84.964787, 45.291601],
#        [-84.732687, 45.289381999999996],
#        [-84.734799, 45.114903],
#        [-84.978695, 45.118437],
#        [-85.22367899999999, 45.117751],
#        [-85.22270499999999, 45.205551],
#        [-85.459181, 45.206568],
#        [-85.462864, 45.229323],
#        [-85.469331, 45.250001],
#        [-85.475966, 45.264005],
#        [-85.487878, 45.280719999999995],
#        [-85.558497, 45.375001999999995],
#        [-85.62507599999999, 45.454602],
#        [-85.67952799999999, 45.506980999999996],
#        [-85.722371, 45.534437999999994],
#        [-85.765964, 45.555538],
#        [-85.800936, 45.566874],
#        [-85.855768, 45.578385999999995],
#        [-85.873227, 45.817903],
#        [-85.855301, 45.824707],
#        [-85.796024, 45.842459999999996],
#        [-85.73484499999999, 45.856275],
#        [-85.624814, 45.875890999999996],
#        [-85.57007399999999, 45.883244],
#        [-85.250075, 45.871334999999995],
#        [-85.239618, 45.87074],
#        [-85.221785, 45.837226],
#        [-85.21654199999999, 45.810747],
#        [-85.21820000000001, 45.794171999999996]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26029', 'name': 'Charlevoix County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-84.605291, 44.85714],
#        [-84.746267, 44.858388],
#        [-84.847309, 44.858036999999996],
#        [-84.848612, 44.898486],
#        [-84.848063, 44.915892],
#        [-84.84978799999999, 44.991219],
#        [-84.849524, 45.029633],
#        [-84.85731899999999, 45.029757],
#        [-84.857452, 45.116707],
#        [-84.734799, 45.114903],
#        [-84.734303, 45.201935999999996],
#        [-84.366827, 45.198761999999995],
#        [-84.36795099999999, 45.069883],
#        [-84.37156, 44.950939999999996],
#        [-84.371757, 44.855028999999995],
#        [-84.477756, 44.856998999999995],
#        [-84.605291, 44.85714]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26137', 'name': 'Otsego County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.929079, 43.132782],
#        [-83.932071, 43.220377],
#        [-83.46073299999999, 43.223130999999995],
#        [-83.458827, 43.036873],
#        [-83.45329699999999, 42.876298999999996],
#        [-83.68938399999999, 42.871263],
#        [-83.686493, 42.783263],
#        [-83.805418, 42.781138],
#        [-83.88397499999999, 42.78169],
#        [-83.922516, 42.780820999999996],
#        [-83.92716399999999, 42.868344],
#        [-83.929867, 42.949791],
#        [-83.92991099999999, 42.956512],
#        [-83.928837, 42.956548],
#        [-83.928384, 43.027847],
#        [-83.929079, 43.132782]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26049', 'name': 'Genesee County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.117494, 43.283719],
#        [-83.00043, 43.284912999999996],
#        [-82.996257, 43.154098999999995],
#        [-82.988755, 43.030299],
#        [-82.986554, 42.982436],
#        [-82.987765, 42.982392999999995],
#        [-82.98364699999999, 42.893741],
#        [-83.003, 42.893181],
#        [-83.023996, 42.890527],
#        [-83.453364, 42.880432],
#        [-83.45908899999999, 43.049172999999996],
#        [-83.460708, 43.232791],
#        [-83.351709, 43.235192999999995],
#        [-83.354418, 43.322257],
#        [-83.120396, 43.327048999999995],
#        [-83.119027, 43.28368],
#        [-83.117494, 43.283719]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26087', 'name': 'Lapeer County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-88.116603, 46.506523],
#        [-88.115843, 46.678380999999995],
#        [-87.991546, 46.679113],
#        [-87.991389, 46.765159],
#        [-88.044709, 46.765353],
#        [-88.043843, 47.124919],
#        [-88.04661399999999, 47.218696],
#        [-87.11211399999999, 47.223268999999995],
#        [-87.11608, 46.158944999999996],
#        [-87.24155499999999, 46.158901],
#        [-87.242885, 45.985087],
#        [-87.61703899999999, 45.986005999999996],
#        [-87.61591399999999, 46.246794],
#        [-88.117407, 46.246618],
#        [-88.116603, 46.506523]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26103', 'name': 'Marquette County, MI'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-83.20052199999999, 42.444838999999995],
#        [-83.42437799999999, 42.43925],
#        [-83.664808, 42.431179],
#        [-83.683122, 42.695991],
#        [-83.68938399999999, 42.871263],
#        [-83.453402, 42.876163],
#        [-83.453364, 42.880432],
#        [-83.102891, 42.888647],
#        [-83.083393, 42.447153],
#        [-83.20052199999999, 42.444838999999995]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'geoid': '05000US26125', 'name': 'Oakland County, MI'},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
#Let's find all the county names and store their data in a dictionary
county_names = []
county_names_dict = {}

for county in michigan_data['features']:
    for m in range(len(county['properties']['name'])):
        if county['properties']['name'][m:m+6] == 'County':
            county_names.append(county['properties']['name'][0:m-1].lower())
            county_names_dict[county['properties']['name'][0:m-1]] = county['properties']['name']
            
print(county_names)
# Out:
# ['alger', 'cheboygan', 'barry', 'kalamazoo', 'menominee', 'grand traverse', 'mackinac', 'kalkaska', 'ottawa', 'roscommon', 'saginaw', 'ogemaw', 'tuscola', 'mason', 'ingham', 'ontonagon', 'branch', 'montmorency', 'osceola', 'wexford', 'alcona', 'allegan', 'huron', 'hillsdale', 'dickinson', 'chippewa', 'leelanau', 'clare', 'baraga', 'alpena', 'gratiot', 'wayne', 'oscoda', 'bay', 'muskegon', 'keweenaw', 'houghton', 'cass', 'crawford', 'newaygo', 'midland', 'gladwin', 'washtenaw', 'mecosta', 'luce', 'oceana', 'jackson', 'montcalm', 'sanilac', 'shiawassee', 'eaton', 'st. joseph', 'schoolcraft', 'st. clair', 'isabella', 'benzie', 'kent', 'emmet', 'monroe', 'gogebic', 'manistee', 'antrim', 'iosco', 'lake', 'livingston', 'delta', 'van buren', 'berrien', 'missaukee', 'macomb', 'iron', 'lenawee', 'ionia', 'arenac', 'calhoun', 'clinton', 'presque isle', 'charlevoix', 'otsego', 'genesee', 'lapeer', 'marquette', 'oakland']

# %%
#Let's classify counties as Democrat or Republican
blue_counties_2016 = []
red_counties_2016 = []

for k, county in enumerate(county_names):
    county_cleaned = re.sub("\.", "", county)
    county_cleaned = re.sub(" ", "", county_cleaned)
    county_cleaned = re.sub(".*-", "", county_cleaned)
    row = mi_voting_data.where(mi_voting_data[1] == county_cleaned)
    if (row.num_rows != 1):
        print("Error: " + county_cleaned)
    else:
        if (row["votes_dem.16"].item() > row["votes_gop.16"].item()):
            blue_counties_2016.append(michigan_data['features'][k])
        else:
            red_counties_2016.append(michigan_data['features'][k])
print("Dem Counties: \n " + str(blue_counties_2016))
print("GOP Counties: \n " + str(red_counties_2016))
# Out:
# Dem Counties:
#  [{'type': 'Feature', 'properties': {'name': 'Kalamazoo County, MI', 'geoid': '05000US26077'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-85.418099, 42.420193999999995], [-85.298879, 42.419849], [-85.299557, 42.419340999999996], [-85.297088, 42.249026], [-85.29362599999999, 42.071553], [-85.76294299999999, 42.069327], [-85.766066, 42.244693], [-85.764352, 42.420669], [-85.53249799999999, 42.421521999999996], [-85.418099, 42.420193999999995]]]]}}, {'type': 'Feature', 'properties': {'name': 'Ingham County, MI', 'geoid': '05000US26065'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-84.60186399999999, 42.769873], [-84.36366, 42.769971], [-84.363659, 42.775777999999995], [-84.158189, 42.776638999999996], [-84.151354, 42.702245], [-84.14174799999999, 42.547264999999996], [-84.14060099999999, 42.508393999999996], [-84.14071299999999, 42.424611], [-84.36480499999999, 42.424693999999995], [-84.364783, 42.422146999999995], [-84.600403, 42.421983999999995], [-84.602949, 42.640243], [-84.602761, 42.76988], [-84.60186399999999, 42.769873]]]]}}, {'type': 'Feature', 'properties': {'name': 'Wayne County, MI', 'geoid': '05000US26163'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-83.420761, 42.093568], [-83.420622, 42.087776999999996], [-83.539396, 42.085598], [-83.54435099999999, 42.239537999999996], [-83.544203, 42.276894], [-83.551907, 42.435165999999995], [-83.343621, 42.441401], [-82.966093, 42.449886], [-82.74990799999999, 42.451091999999996], [-82.83024999999999, 42.373492], [-82.94548499999999, 42.347395999999996], [-82.95975, 42.340033], [-82.98919699999999, 42.332481], [-83.014076, 42.331320999999996], [-83.026234, 42.32891], [-83.063637, 42.316857], [-83.08001999999999, 42.307172], [-83.097704, 42.289674999999995], [-83.11202999999999, 42.260587], [-83.126361, 42.238412], [-83.127237, 42.234761999999996], [-83.134384, 42.174620999999995], [-83.125304, 42.137556], [-83.11922799999999, 42.125263], [-83.122401, 42.114269], [-83.127526, 42.104968], [-83.13212299999999, 42.088139], [-83.145691, 42.053858], [-83.14945, 42.040264], [-83.143956, 42.02793], [-83.18457599999999, 42.028506], [-83.190317, 42.032457], [-83.19734299999999, 42.034101], [-83.199756, 42.035241], [-83.201544, 42.039314999999995], [-83.209519, 42.04027], [-83.21684599999999, 42.04409], [-83.219674, 42.049119999999995], [-83.230254, 42.048733999999996], [-83.228811, 42.054566], [-83.23208199999999, 42.055333999999995], [-83.234286, 42.059287999999995], [-83.236615, 42.058240999999995], [-83.243675, 42.061923], [-83.248618, 42.060713], [-83.250222, 42.063932], [-83.254728, 42.0643], [-83.25147899999999, 42.067946], [-83.254502, 42.068211], [-83.257978, 42.073975999999995], [-83.26247699999999, 42.073025], [-83.265039, 42.06917], [-83.267372, 42.069099], [-83.269476, 42.071342], [-83.26921899999999, 42.075423], [-83.276994, 42.076328], [-83.274833, 42.080346], [-83.27798399999999, 42.079342], [-83.279917, 42.080283], [-83.280208, 42.081722], [-83.27698699999999, 42.082419], [-83.282274, 42.083929], [-83.28018399999999, 42.085846], [-83.283017, 42.085817999999996], [-83.283165, 42.089470999999996], [-83.284978, 42.089731], [-83.284041, 42.088834999999996], [-83.285141, 42.087748999999995], [-83.287235, 42.088243999999996], [-83.28586299999999, 42.090889], [-83.288521, 42.089825], [-83.294814, 42.094378], [-83.420761, 42.093568]]]]}}, {'type': 'Feature', 'properties': {'name': 'Muskegon County, MI', 'geoid': '05000US26121'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-86.38461699999999, 43.472255], [-86.039491, 43.467447], [-86.03895299999999, 43.293518999999996], [-85.790448, 43.293003], [-85.790662, 43.205166999999996], [-85.908388, 43.20592], [-85.90743499999999, 43.118911], [-86.146166, 43.117394999999995], [-86.375058, 43.119056], [-87.107669, 43.118243], [-87.147166, 43.379858999999996], [-87.14033099999999, 43.471436], [-86.87507599999999, 43.473689], [-86.38461699999999, 43.472255]]]]}}, {'type': 'Feature', 'proper ...
# GOP Counties:
#  [{'type': 'Feature', 'properties': {'name': 'Alger County, MI', 'geoid': '05000US26003'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-85.864155, 46.702662], [-85.864932, 46.504757999999995], [-86.364953, 46.505852], [-86.36526099999999, 46.331928999999995], [-86.615397, 46.333262999999995], [-86.615601, 46.158691], [-87.11608, 46.158944999999996], [-87.11663399999999, 46.494808], [-87.112245, 46.749925999999995], [-87.112695, 47.817997999999996], [-86.94062199999999, 47.749905], [-86.949226, 47.749905], [-86.75012, 47.67196], [-86.75012, 47.674910999999994], [-86.631321, 47.624919999999996], [-86.634344, 47.624919999999996], [-86.625125, 47.617767], [-86.625125, 47.620008], [-86.50013, 47.568324], [-86.25013899999999, 47.477903], [-86.25013899999999, 47.474447999999995], [-86.125141, 47.423468], [-86.125142, 47.416744], [-86.020032, 47.374962], [-86.027345, 47.374961], [-86.00014499999999, 47.361883], [-86.00014399999999, 47.367278999999996], [-85.854862, 47.305482], [-85.858727, 47.249976], [-85.854607, 47.249977], [-85.864155, 46.702662]]]]}}, {'type': 'Feature', 'properties': {'name': 'Cheboygan County, MI', 'geoid': '05000US26031'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-84.719578, 45.809332], [-84.695497, 45.806269], [-84.67654399999999, 45.801519], [-84.639253, 45.787026], [-84.625044, 45.779443], [-84.586739, 45.750001999999995], [-84.568844, 45.738077], [-84.54171199999999, 45.723721999999995], [-84.51003899999999, 45.709432], [-84.483475, 45.700693], [-84.44692599999999, 45.694703999999994], [-84.40664, 45.692488], [-84.366314, 45.695872], [-84.353121, 45.699397], [-84.250045, 45.739827999999996], [-84.201062, 45.752275], [-84.204263, 45.626247], [-84.25202, 45.625997999999996], [-84.24750999999999, 45.430872], [-84.24938, 45.282073], [-84.246613, 45.282073], [-84.246634, 45.198718], [-84.433876, 45.198969999999996], [-84.734303, 45.201935999999996], [-84.72985899999999, 45.401083], [-84.73259499999999, 45.81033], [-84.719578, 45.809332]]]]}}, {'type': 'Feature', 'properties': {'name': 'Barry County, MI', 'geoid': '05000US26015'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-85.541006, 42.768175], [-85.07424499999999, 42.770784], [-85.075582, 42.683589], [-85.07521899999999, 42.613859999999995], [-85.071609, 42.421428], [-85.35157799999999, 42.419722], [-85.543191, 42.421433], [-85.543239, 42.590905], [-85.545107, 42.681428], [-85.545564, 42.768139], [-85.541006, 42.768175]]]]}}, {'type': 'Feature', 'properties': {'name': 'Menominee County, MI', 'geoid': '05000US26109'}, 'geometry': {'type': 'MultiPolygon', 'coordinates': [[[[-87.636344, 45.898846], [-87.61761299999999, 45.898841999999995], [-87.61703899999999, 45.986005999999996], [-87.367843, 45.985313], [-87.368403, 45.899217], [-87.32572499999999, 45.898623], [-87.327472, 45.550506999999996], [-87.12911799999999, 45.550484999999995], [-87.127826, 45.409487], [-87.17116999999999, 45.35254], [-87.315422, 45.240657], [-87.405694, 45.201969], [-87.44250799999999, 45.076434], [-87.585388, 45.096925], [-87.59187999999999, 45.094688999999995], [-87.62771699999999, 45.10335], [-87.631535, 45.106224], [-87.648191, 45.106367999999996], [-87.652512, 45.108633], [-87.65995199999999, 45.107512], [-87.661296, 45.112566], [-87.67244699999999, 45.121294], [-87.678209, 45.130084], [-87.675816, 45.135059], [-87.68390199999999, 45.144135], [-87.692375, 45.149505], [-87.703492, 45.152206], [-87.70953899999999, 45.15869], [-87.71790999999999, 45.161190999999995], [-87.727768, 45.169596], [-87.736104, 45.172244], [-87.73521, 45.177642], [-87.741732, 45.198201], [-87.736339, 45.204653], [-87.726198, 45.209391], [-87.726952, 45.218948999999995], [-87.72135399999999, 45.226847], [-87.724992, 45.23214], [-87.71826399999999, 45.238333], [-87.711339, 45.239965], [-87.711315, 45.252396], [-87.707758, 45.258637], [-87.71045, 45.259324], [-87.705643, 45.266104], [-87.69878, 45.26942], [-87.69824799999999, 45.281512], [-87.69034099999999, 45.290217], [ ...

# %%
#Now we write our data to a JSON file, which will allow us to import it back to Plotly.
red_data_2016 = {"type": "FeatureCollection"}
red_data_2016['features'] = red_counties_2016

blue_data_2016 = {"type": "FeatureCollection"}
blue_data_2016['features'] = blue_counties_2016

with open('florida-red-data-2016.json', 'w') as f:
    f.write(json.dumps(red_data_2016))
with open('florida-blue-data-2016.json', 'w') as f:
    f.write(json.dumps(blue_data_2016))

# %%
import plotly.plotly as py
import plotly.graph_objs as graph_objs

mapbox_access_token = 'pk.eyJ1IjoiYWRuYW5oZW1hbmkiLCJhIjoiY2l5N3RnY3M4MDAxZTJxb3Y3anlsbnJ0ZSJ9.REcsaI8vU6ylkrpkjuMtqA'

data = graph_objs.Data([
    graph_objs.Scattermapbox(
        lat=['45.5017'],
        lon=['-73.5673'],
        mode='markers',
    )
])
layout = graph_objs.Layout(
    height=600,
    autosize=True,
    hovermode='closest',
    mapbox=dict(
        layers=[
            dict(
                sourcetype = 'geojson',
                source = 'https://raw.githubusercontent.com/adnanhemani/data8-assets/master/michigan-red-data-2016.json',
                type = 'fill',
                color = 'rgba(163,22,19,0.8)'
            ),
            dict(
                sourcetype = 'geojson',
                source = 'https://raw.githubusercontent.com/adnanhemani/data8-assets/master/michigan-blue-data-2016.json',
                type = 'fill',
                color = 'rgba(40,0,113,0.8)'
            )
        ],
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=44.5,
            lon=-84.8
        ),
        pitch=0,
        zoom=4.5,
        style='light'
    ),
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='county-level-choropleths-python')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~data8/2.embed" height="600px" width="100%"></iframe>
